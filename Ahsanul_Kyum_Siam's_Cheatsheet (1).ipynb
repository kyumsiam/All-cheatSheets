# %% [markdown]
# Main video f

# %% [markdown]
# ***Steps***
#
#
# 1.   Clean the Data (null value detect,fill the null value,Deal with dublicates,Feature engineering ,Outlier detection)
# 2. OR (if want to See relationship instant See group By and use Barchart to show that)
#
# 3.   Make two Parts of the dataset (Numerical and Categorical)

# %% [markdown]
# # How to Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# 1) Pandas is a Python library used for working with data sets.
# It has functions for analyzing, cleaning, exploring, and manipulating data
#
# 2)Numpy is a Python library that provides a multidimensional array object
#
# 3)Matplotlib is a low level graph plotting library in python that serves as a visualization utility.
#
# 4)Seaborn is a library for making statistical graphics in Python. It builds on top of matplotlib and integrates closely with pandas data structures.
#
# 5)This line tells Jupyter to display Matplotlib plots directly in the output of the notebook othewise use plt.show()

# %%
# How to import a Library
# !pip install numpy

# %% [markdown]
# # Import From different Source

# %%
#df = pd.read_csv('File_name')
#df = pd.read_excel('File_name')

# %%
# import csv file  face error use this
df = pd.read_csv('Diwali Sales Data.csv', encoding= 'unicode_escape')

# %%
#Available Datasets
sns.get_dataset_names()

# %%
#import the sns load dataset
df=sns.load_dataset('titanic')

# %% [markdown]
# The Python-specific encoding unicode_escape is a dummy encoding that converts all non-ASCII characters into their \uXXXX representations. Code points above the ASCII 0-127 range but below 256 are represented in the two-digit form \xXX.

# %% [markdown]
# # Making  DataFram,Series,Array,list,set,tuple,distionary

# %% [markdown]
# ***Python Builten Data structure***
#
#
# *   List [MOD] {Mutable,order available,Duplicate available}
# *   Tuple [IOD] {Immutable,Order available,Duplicate available}
# *   Set [I Uo Ud] {Immutable, unordered, unduplicate}
# *   Distionary

# %% [markdown]
# 1) What is Series?
#
# pandas series is a one column of pandas Dataframe. It takes list of strings .
#
# 2) Pandas dataframe can be made from dictionary, list and many more things .

# %% [markdown]
# ***Making Empty Data Frame***

# %%
df = pd.DataFrame()
df=pd.Series()
# Out:
# <ipython-input-6-1539a1e53a20>:3: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df=pd.Series()

# %% [markdown]
# ***Making Pandas DataFrame AND Series***
#
#
# **Make 3 List then Convert them to DataFrame and Series**

# %%
# Making DataFrame
# First making 3 list  :
a =[['motin',15],
      ['siam',13],
      ['Akash',40]]

# Making DataFrame using Columns Name :
df = pd.DataFrame(data=a,columns=['Name','Age'])

# %%
# Copy Some Columns from the main DataFrame [ No method like  replace are available , so make new dataframe and input them]  ]
df1=pd.DataFrame(df,columns=['a','b','g'])

# %%
# Making Series
a =[['motin',15],
      ['siam',13],
      ['Akash',40]]
df1=pd.Series(a)

# %% [markdown]
# ***Copying a column from a pandas DataFrame to a existing Dataframe***

# %%
df1['Age']=df['Age']

# %% [markdown]
# ***Make a new dataframe using some columns of an another dataframe***

# %%
#Make a new DataFrame which are numerical
df2=pd.DataFrame(data=df,columns=(['survived','pclass','age','sibsp',	'parch'	,'fare']))

# %% [markdown]
# ***Based on any condition making new dataFrame***

# %%
df1=df.[df['Age']==1]

# %% [markdown]
# ***Merge Dataset***

# %%
#left - Merge the dataset with Left dataset
final_df=pd.merge(df,df_country,on='Country Code',how='left')

# %% [markdown]
# ***Making 1D Array***

# %%
s=np.array([1,2,3,4]) [#so the third bracket or first braket anything can be used]
type(s)
print(s.ndim)
print(s)
# Out:
# 1
# [1 2 3 4]

# %%
#or
s=np.array((1,2,3,4)) #[Extra Brackets are indicates the Dimention]
type(s)
print(s.ndim)
print(s)
# Out:
# 1
# [1 2 3 4]

# %% [markdown]
# ***Making 2D Array***

# %%
s1=np.array(((1,2),(3,4))) #[Extra Brackets are indicates the Dimention]
type(s1)
s1.ndim
# Out:
# 2

# %% [markdown]
# # Attribute , Function , method

# %% [markdown]
# 1) Difference Attributes and Methods
#
# Methods - Use BRACKETS
# Actions like describing is a statistics method, sorting is an action
# **example : df.describe( ) , df.sort_values ( )**
#
# Attributes are the Features . That don't use any brackets
# Attributes - NOT USE BRACKETS
# like the feature the Data Frame has like Row num, Col num
# **example: df.shape, df.dtype**

# %%
dir(pd.DataFrame())

# %%
# df.shape , df.size , df.ndim,

# %% [markdown]
# # Other Works like split , change Datatype

# %% [markdown]
# 1) **Change the Datatype of a column**

# %%
df.col_name.astype('int')

# %% [markdown]
# ***2) Rename the Column Name***

# %%
#use 2nd Brackets like a dictionary
df.rename({'Amount':'a'})

# %% [markdown]
# # Explanatory Data Analysis

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
#
# ***Steps 1:(CLeaning and Seeing the Statistical Measurements) Not Included***
#
# ***Substep 1:*** (Check the Null and Duplicate Values)
# *   Check the data Using df.info() , df.isnull().sum() , df.isnull()
#
# ***Handle the ROW dublicates Column Dublicates in Feature selection***
#
# * df.duplicated()
#
# * df.drop_duplicates(inplace=True)
#
#
# **When to Drop a column**
#
#
# *   The column has more  then 75% Missing Values then Drop this Column
# *   Drop The Any column which has all null  values : df.drop (['col_name'],
#     ['col_name']),axis=1,inplace=True) [Row*column so 0 - Row , 1 - Columns]
# *   Drop  missing from Whole dataset values use : df.dropna(axis=0 / axis=1)
#     0- Row , 1- Column
#
# ***Subplot 2 :***
# ***For fill the value with mean, median, mode or forward and background interpulation***
#
#
# *    Fill the Null value with arbitary value  :(Not recomended)
#    df.fillna( value , inplace = True)
# *   Fill specific columns with arbitary Value
# df[" col name"].fillna( value , inplace=True)
#
#
# *  For fill the value with mean value(When data has no outlier then use this, if outlier then this will be Recomended to use Median)
# df[" col name"].fillna( df["col name"].mean() , inplace=True)
#
#
# * Forward Filling Imputation :
# df1['Age'] = df1['Age'].ffill() [No Recomended]
#
# *  Backward Filling Imputation :
#  df1['Age'] = df1['Age'].bfill() [No Recomended]
#
#
# iv)df.describe()

# %% [markdown]
# ***Step 2 :*** (For Excle data) Analysis the simple things
#
#  i)Use Sns Countplot to visualise the different items in the column
#
#  ii)Then Group by the column with amount or order and then use Barplot to see the Relation

# %% [markdown]
# # Group by

# %% [markdown]
# **1**) Group By
#
# ax=df.groupby(['col_name'],as_index=False)['col_name].sum().sort_values(by='Order',ascending=False).head(10)
#
# For visualize the group data use Barplot

# %%
# plotting a bar chart for gender vs total amount

sales_gen = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
sns.barplot(x = 'Gender',y= 'Amount' ,data = sales_gen)

# %% [markdown]
# # Different Graphs

# %% [markdown]
# ***Important Talks***
# *   From age data use Line chart (several Groups)
# *

# %% [markdown]
# Fixed the SIZE of the Graphs
#
# sns.set(rc={'figure.figsize':(15,5)})
#
# 1) Countplot: **Show which Gender is highest(1 Column)**
#
#   Countplot is used in 1 columns to the the amount of different values in the Columns
#
# ***sns.countplot(x='col_name',data=df)***

# %%
#Countplot
sns.countplot(x='col_name',hue='col_name', data=df)

# %% [markdown]
# *** 2) Barplot :Show which Gender is highest in terms of Amount (2 Column)
#
#   Showing two columns Use Barplot x and y ,***
#
#   sns.barplot(data=groupdf,x='' , y= '')
#
#   http://localhost:8888/notebooks/Pictures/Python%20Projects/Diwali_Sales_Analysis.ipynb

# %%
# plotting a bar chart for gender vs total amount
sales_gen = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
sns.barplot(x = 'Gender',y= 'Amount' ,data = sales_gen)

# %%
#Barplot
sns.barplot(data=groupdf,x='' , y= '')

# %% [markdown]
# Distribution Plot

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # SubPlots

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ***Heatmaps***

# %%
https://www.youtube.com/watch?v=eAGjpFBJUCw&t=7s

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# Feature engineering Divides in 4 parts
#
#
# *   Feature Transformation
# *   Feature constraction
# *   Feature Selection
# *   Feature Extraction

# %% [markdown]
# Feature Transformation
#
#
# *  Missing value iputation
# *  Handling Categorical Features
# *   Outlier Detection
# *   Feature Sacaling

# %% [markdown]
# # Transformer (Technique)
#
# [Goal](https://www.youtube.com/watch?v=cTjj3LE8E90&list=PLKnIA16_Rmvbr7zKYQuBfsVkjoLcJgxHH&index=30) : Transfor the data to Normal distribution
#
#
# 1.   Function Transformer
# 2.   Power Transformer (Box-coxs, Yeo johnson)
# 3.   Quantile Transformer

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #  Function Transfomation
# End Goal convert the dataset Normal distribution
#
# Impact algorithms : Logistic Regression,
#
# Not impact : Decession Tree,
#
# *   Log [Transformation]((https://youtu.be/cTjj3LE8E90?si=uN2P7L1RHygj7awz))
# *   Reciprocal
# *  square
# *square root
# *  Custom

# %% [markdown]
# **Function Transformer Code**
#
# How to check the normality of data
#
#
# *   sns.displot
# *   pd.skew() - IF 0 that means data is normal
# *   QQ plot - Statisitcs

# %% [markdown]
# # Log transformation
#
# 1.   Log transformation not used to Negative values
# 2.   Log transformation used Right skewed data [Bigger tail in Right side]
#
# skewness{ In which side the tail big this called that side skewed}

# %% [markdown]
# # Feature Selection
#
# For using Chi-Square feature selection have campus x used MinmaxScaler [link](https://www.youtube.com/watch?v=xOccYkgRV4Q&list=PLKnIA16_Rmvbr7zKYQuBfsVkjoLcJgxHH&index=29)

# %% [markdown]
# Why Use ?
# When Column numbers are very High
# Ans :
#
# 1)Curse of Dimensionality
#
# 2)Computational Complexity
#
# 3) interpretability
#
# (https://www.youtube.com/watch?v=hRTe7tSkR2k) **Campus X**

# %% [markdown]
# Types of Feature Selection in Campus x
#
# 1)Filter Based Feature selection
#
# 2)

# %% [markdown]
# Feature selection methods used in Research
#
# 1)Boruta Feature selection
#
# 2)Using Spss CHi Square test

# %% [markdown]
# Some Methods Have to DO
#
# 1) Handeling the Dublicate Columns [https://colab.research.google.com/drive/1OIT_QgXE-xUDk_CaDnkcMUENplktRv4r#scrollTo=TRCIxxfN57S2]

# %% [markdown]
# # Feature Extraction
# Means extra Features from the existing features . Select that features which has high variance

# %% [markdown]
# Algos :
#
# 1) PCA

# %% [markdown]
# #Feature Scaling
#
# [link](https://(www.youtube.com/watch?v=qR3C-q9UrLk )
#
#
# Source : Campus X + video Link
#
# N.B : Before Feature scaling Always recomended to do ***Train test split*** otherwise there be a chance of Data leckage issue.
#
#
# 2 Types through Campus X
#
#
# *   Standardization(Can't control effect of Outliers)
# *   Normalzation (Minmaxscaller, RobustScaler,

# %% [markdown]
# # Questions before Using Feature scaling in Dataset
#
#
#
# 1.  Is feature Scaling required based on Algothims.
#
# 2.   Which one to use Standarization or Normalization (Most of the cases have to use StandardScaler)
# 3.   Minmaxscaler used when the minmax is known from previous for image dataset (0,255)

# %% [markdown]
# # Quick View
#
#
#
# 1.   For Mean=0, SD=1, centering use - Standarization
# 2.  For convert to range(0,1) - Minmaxscaler
# 3.   For handling outlier - Robusscalar
# 4.   For sparse[where the amount of 0 highest] dataset - MaxAbsScaler

# %% [markdown]
# ***Questions For Basic knowledge with Ans***
#
# *   What,why,type Feature Scaling
# *   How effect feature Scaling to the data
# *   For which type of Algorithms feature Scaling is important
# *   Advantages of Feature Scaling
# *   Graphical Transformation Of Data Must see

# %% [markdown]
# # Standarization (Can't control effect of Outliers)
#
# Standarization also called Z score normalization. After standarization the new new number will have mean(MU)= 0 and Standard Deviation(SD)=  1 .
#
# So in the picture can see the transformation of Mean from the Middle to Center where the Mean in (0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ***Links***
#
# 1) Graphical Transformation the Normalization Problem : https://www.youtube.com/watch?v=sxEqtjLC0aM
#
# 2)  https://www.kaggle.com/code/discdiver/guide-to-scaling-and-standardizing/notebook
#
# https://towardsdatascience.com/scale-standardize-or-normalize-with-scikit-learn-6ccc7d176a02#:~:text=Use%20StandardScaler%20if%20you%20want,to%20have%20a%20light%20touch.
#
# [Important Links]

# %% [markdown]
# ***So first to find the relation in Columns Using***
#
# *df.describe()*  [See the 25% , 75%, Median Vlaues and compare the other columns] Show  mean and SD value for Standarization and see min max for normalization

# %% [markdown]
# ***Feature Scaling is needed to Convert each column into same scale . Normalize the Data . Suppose dataset has two columns . Height in Gram , and Weight in Kg . So when distance the difference between 2 rows the difference imbalancement in Height and weight demage the performance . Have to scale the data Overwise Height(More Value) Columns will more preference.***
#
# ***Techniques of Feature Scalling***
# If we understand the data is not Normally distributed go to Normalization technique
#
#
# Avoid the Normalize Term which is confusing
#
# ---
#
#
# ***Four Types of scales :  MinMaxScaler, RobustScaler, StandardScaler, and Normalizer***
#
#
#
# ---
#
#
#
# ---
#
#
# ***MinMaxScaler***: MinMaxScaler preserves the shape of the original distribution. It doesn’t meaningfully change the information embedded in the original data.
# ***Note that MinMaxScaler doesn’t reduce the importance of outliers.***
# The default range for the feature returned by MinMaxScaler is 0 to 1
# MinMaxScaler isn’t a bad place to start, unless you know you want your feature to have a normal distribution or you have outliers and you want them to have reduced influence.
#
# ---
#
#
# ---
# ***RobustScaler*** transforms the feature vector by subtracting the median and then dividing by the interquartile range (75% value — 25% value).Use RobustScaler if you want to reduce the effects of outliers, relative to MinMaxScaler.
#
# ---
#
#
# ---
#
#
#
# ---
#
#
# *   Standarization ( Before using this  Ensure the data follows Stadard Normal distribution with Mean = 0, SD = 1 ) ((X- Mean) / SD)
# *   Minmax Scaler ( (x-x min)/x max-x min) ( Before using this  Ensure the data range From 0 to 1 )
#
#
#
# **Difference between Minmax Scaler VS Normalizer**
#
# *   MinMaxScaler is applied column-wise, Normalizer is apllied row-wise
#
# So perfer MinmaxScaler so scale the data as works with CLoumns, Normalizer Scale the Every row in same Range that isn't Required . Always Use MinMaxscaler.
#
#
#
#
# ***Sklearn library of pyhton which has so many methods minmaxscaler, standardscalers***
#
#
# *Feature Scaling used for in 3 type of models*
#
# *   Type 1 : Distance type algorithm like :KNN, ***(must use Feature  Scaling)***
# *   Type 2 : Gradiant Decent type algorithm (Deep learning Algos, Linear ,
#     logistic Regression) **(Use Feature Scaling)**
# *   Type 3 :  Decision Tree type algorithm (Bagging,Bosting,Random Forest, XG-BOOST) ***(Not need to use Scaling)***
#
# **Advantages**
# *   Faster Convergence
# *   Computing Distance Appropriately ( The Graph Change )
#
#
# ***Conclusion:***
# Deep learning algorithms often call for zero mean and unit variance. Regression-type algorithms also benefit from normally distributed data with small sample sizes.
#
# Here the comparision of 4 Scales Why use this
# https://docs.google.com/spreadsheets/d/1l3LC7Yr88AAcPRVD3yfr0lVFZ_M8lscBHNl77fcWjPY/edit#gid=0

# %% [markdown]
# ***When Use Standarization or Nomalizations***
#
#
#
# *   To avoid Data leakage issue Divide the Test and training data before Normalization or Standardization
#
# *   Generally For continuous data use Standarization like ( 56,68,90,120,456,908)
# *   For Discreate data like when columns have value only [ 0, 1 , 2 ] use   normalization which makes value form (0-1)
# *   Generally, no right and wrong answer
# *   Stadarization is used when the data follows Guissain Distribution
# *   In the case of neural Network , normalization is prefered as data has no
#     assumpation
# *   Standarization is preffered over Normalization when the data has many
#     outliers

# %% [markdown]
# # **StandardScaler Code**
#
# [Github link:](https://github.com/campusx-official/100-days-of-machine-learning/tree/main/day24-standardization)
#
# Why doesn't effect the StandardScale
# Means if use or not use doesn't impact the accuracy
#
# *   Random Forest
# *   Decesion Tree
# *   X Boost
# *   Gradiant Boost

# %%
#First divide the dataset in train test (it's recomended that solve the data leckage issue)
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df.drop('PURCHASR',axis=1),df['PURCHASR'],test_size=0.3,random_state=42)

x_train.shape,x_test.shape

# %%
from sklearn.preprocessing import StandardScaler

#From the StandardScaler class make a object name scaler
scaler =StandardScaler()

#fit the scaler to the train set, it will learn the parameters
scaler.fit(x_train)

#transform train and test sets
x_train_scaled =scaler.transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
# Scale takes the DataFrame but back the numpy array
scaler.mean_

# %%
# Transform the array to pandas DataFrame
x_train_scaled=pd.DataFrame(x_train_scaled,columns=x_train.columns)
x_test_scaled=pd.DataFrame(x_test_scaled,columns=x_test.columns)

# %%
# Main goal of standard Deviation scale the dataset to make the mean 0 and SD 1
print(np.round(x_train.describe()))
print(np.round(x_train_scaled.describe(),1))

# %%
# Shape of the Data in Subplots
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

ax1.scatter(X_train['Age'], X_train['EstimatedSalary'])
ax1.set_title("Before Scaling")
ax2.scatter(X_train_scaled['Age'], X_train_scaled['EstimatedSalary'],color='red')
ax2.set_title("After Scaling")
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Distribution Plot
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Salary Distribution Before Scaling')
sns.kdeplot(X_train['EstimatedSalary'], ax=ax1)

# after scaling
ax2.set_title('Salary Distribution Standard Scaling')
sns.kdeplot(X_train_scaled['EstimatedSalary'], ax=ax2)
plt.show()

# %% [markdown]
# # Difference in Accuracy After scaling

# %%
#Logistic Regression Reacts on that
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr_scaled = LogisticRegression()
lr.fit(X_train,y_train)
lr_scaled.fit(X_train_scaled,y_train)
y_pred = lr.predict(X_test)
y_pred_scaled = lr_scaled.predict(X_test_scaled)
from sklearn.metrics import accuracy_score
print("Actual",accuracy_score(y_test,y_pred))
print("Scaled",accuracy_score(y_test,y_pred_scaled))

# %%
#Decision Tree doesn't React on Scaling
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt_scaled = DecisionTreeClassifier()
dt.fit(X_train,y_train)
dt_scaled.fit(X_train_scaled,y_train)
y_pred = dt.predict(X_test)
y_pred_scaled = dt_scaled.predict(X_test_scaled)
print("Actual",accuracy_score(y_test,y_pred))
print("Scaled",accuracy_score(y_test,y_pred_scaled))

# %% [markdown]
# # Use of Standarization on the Case of Outlier
#
# Can't control effect of Outliers.

# %% [markdown]
# # Type 2 - Normalization
#
#
# *   Minmaxscaling(Sometimes people say this as Normalization)
#
# *   Mean Normalization (x_scaled value = (x-x mean)/x max-x min) ( Range [-1,1], Used when need data centering ) NO class in Sklearn , have to Raw coding
#
# *   Max absolute Scaling x_scaled = x - |max x| , Classname in sklearn [MazxmAbsScaler] Used for sparse data
# [Where amount of 0 is large]
#
# *   RobustScaling (x_scaled = (x - median x)/IQR)
# Used when the data has ***outliers***.
#
# here : IQR= (75th per - 25th per)

# %% [markdown]
# # Minmaxscaler CODE
#
# [Github link :](https://github.com/campusx-official/100-days-of-machine-learning/tree/main/day25-normalization)
#
# *   Minmax Scaler ( (x-x min)/x max-x min) ( Before using this  Ensure the data range From 0 to 1 )
#
# *   If there any outlier can't minimize it to (0,1) Range so the scale works poor.
#
#
#
# Not converting the Mean or Standard Deviation ensure the Range .

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Divide the dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop('Class label', axis=1),
                                                    df['Class label'],
                                                    test_size=0.3,
                                                    random_state=0)

X_train.shape, X_test.shape

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# fit the scaler to the train set, it will learn the parameters
scaler.fit(X_train)

# transform train and test sets
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Out:
# pandas.core.frame.DataFrame

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %%
print(np.round(X_train.describe(), 1))
print(np.round(X_train_scaled.describe(), 1))
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    0.654321    0.367921    0.065376    0.063599    0.062858
# std      0.486592    0.418036    0.182540    0.137843    0.134343    0.096995
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.500000    0.247612    0.000000    0.000000    0.015440
# 50%      0.000000    1.000000    0.346569    0.000000    0.000000    0.028213
# 75%      1.000000    1.000000    0.472229    0.125000    0.000000    0.060508
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

ax1.scatter(X_train['Alcohol'], X_train['Malic acid'],c=y_train)
ax1.set_title("Before Scaling")
ax2.scatter(X_train_scaled['Alcohol'], X_train_scaled['Malic acid'],c=y_train)
ax2.set_title("After Scaling")
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Before Scaling')
sns.kdeplot(X_train['Alcohol'], ax=ax1)
sns.kdeplot(X_train['Malic acid'], ax=ax1)

# after scaling
ax2.set_title('After Standard Scaling')
sns.kdeplot(X_train_scaled['Alcohol'], ax=ax2)
sns.kdeplot(X_train_scaled['Malic acid'], ax=ax2)
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Malic acid Distribution Before Scaling')
sns.kdeplot(X_train['Malic acid'], ax=ax1)

# after scaling
ax2.set_title('Malic acid Distribution After Standard Scaling')
sns.kdeplot(X_train_scaled['Malic acid'], ax=ax2)
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
sns.pairplot(df1)

# %% [markdown]
# ***Code For StanDarization***

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#Make a new DataFrame which are numerical
df2=pd.DataFrame(data=df,columns=(['survived','pclass','age','sibsp',	'parch'	,'fare']))

# %%
#StandardScaler
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
df2=scaler.fit_transform(df2)
# After Scaling the pandas dataFrame becomes numpy Array , so make it again it Pandas Array

# %%
df2=pd.DataFrame(df2,columns=(['survived','pclass','age','sibsp',	'parch'	,'fare']))

# %%
df2.describe()
# Out:
#            survived        pclass           age         sibsp         parch  \
# count  8.910000e+02  8.910000e+02  7.140000e+02  8.910000e+02  8.910000e+02
# mean   3.987333e-17 -8.772133e-17  2.388379e-16  4.386066e-17  5.382900e-17
# std    1.000562e+00  1.000562e+00  1.000701e+00  1.000562e+00  1.000562e+00
# min   -7.892723e-01 -1.566107e+00 -2.016979e+00 -4.745452e-01 -4.736736e-01
# 25%   -7.892723e-01 -3.693648e-01 -6.595416e-01 -4.745452e-01 -4.736736e-01
# 50%   -7.892723e-01  8.273772e-01 -1.170488e-01 -4.745452e-01 -4.736736e-01
# 75%    1.266990e+00  8.273772e-01  5.718310e-01  4.327934e-01 -4.736736e-01
# max    1.266990e+00  8.273772e-01  3.465126e+00  6.784163e+00  6.974147e+00
#
#                fare
# count  8.910000e+02
# mean   3.987333e-18
# std    1.000562e+00
# min   -6.484217e-01
# 25%   -4.891482e-01
# 50%   -3.573909e-01
# 75%   -2.424635e-02
# max    9.667167e+00

# %% [markdown]
# # Outlier Treatment

# %% [markdown]
# Detect Outliers Using this
#
# *   Boxplot
# *   Histogram
# *   Scatter Plot
# *   Z-Score
# *   Inter Quantile Range

# %% [markdown]
# ***In Which situations outliers are important for the Data***
#
# *   Time Series Data (Where to forecast the future)
#
# [So not remove the outlier]

# %% [markdown]
# ***The Models that are not carrying about Outliers***
#
#
# *   KNN , Decision Tree, SVM , Naive Bayes Ensemble Methods

# %% [markdown]
# *Using 3-Sigma Technique (Standard Deviation)*

# %%
# Function to Detection Outlier on one-dimentional datasets.
import statistics
def find_anomalies(data):
    #define a list to accumlate anomalies
    anomalies = []

    # Set upper and lower limit to 3 standard deviation
    random_data_std = statistics.stdev(data)
    random_data_mean = statistics.mean(data)
    # 3-standard deviation

    anomaly_cut_off = random_data_std * 3

    lower_limit  = random_data_mean - anomaly_cut_off
    upper_limit = random_data_mean + anomaly_cut_off

    # Generate outliers
    for outlier in data:
        if outlier > upper_limit or outlier < lower_limit:
            anomalies.append(outlier)
    return anomalies

# %%
list1=find_anomalies(df.fare)

# %%
#Number of Outlier
print(len(list1))
print(len(df))
# Out:
# 20
# 891

# %%
df.fare.skew()
# possitively Skewed
# Out:
# 4.787316519674893

# %%
# Fee hand to e
sns.kdeplot(df.fare)
#Possitively skewed Graph
# Out:
# <Axes: xlabel='fare', ylabel='Density'>

# %% [markdown]
# ***The process of making the data more normal***

# %%
# Transfor to Log to convert it normal distribution
df['transformed_data']=np.log(df.fare)
sns.kdeplot(df.transformed_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <Axes: xlabel='transformed_data', ylabel='Density'>

# %% [markdown]
# ***Box Plot Approach***
#
# 1.   List item
# 2.   List item

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %% [markdown]
# # Numerical and Cetegorical Data analysis

# %%
## http://localhost:8888/notebooks/Pictures/Python%20Projects/Categorical%20and%20Numerical%20Analysis_Final.ipynb
## https://www.youtube.com/watch?v=eAGjpFBJUCw&t=7s (Heatmaps)
## http://localhost:8888/notebooks/Pictures/Python%20Projects/Feature_Binning_Final.ipynb
## http://localhost:8888/notebooks/Pictures/Python%20Projects/Feature_Encoding_Final.ipynb

# %%
# Heatmap
1)sns.heatmap(pivot_table, cbar=False, linewidth=0.5, annot=True , fmt= 'd' , cmap='winter')

2)plt.figure(figsize=(6,6))
   sns.heatmap(telco_base_data.corr(), cmap='Paired')

# %% [markdown]
# ***Important Talks***
#
# *   From age data use Line chart
# *   List item

# %% [markdown]
# ***Univariate Analysis***

# %% [markdown]
# ***Types of Univariavte analyis***
#
#
# *    Categorical Data (Use Value counts, Countplot )
# *   Numerical Data  Use df.describe)

# %% [markdown]
# ***Bi Variate Analysis***

# %% [markdown]
# ***Types of Bi variate***
#
# *   Numerical ( Correaltion , and Use Heatmaps
# *   Categorical

# %% [markdown]
# # Encoding

# %% [markdown]
# Types of data
#
#
# *   Numerical
#
# 1.   Discreate data
# 2.   Continues data
#
#
# *   Categorial Data
#
# 1.   Nominal data
# 2.   Ordinal data

# %% [markdown]
# #***Type of Encoding***
#
#
# 1.Label encoding (for target variable only , Specially designed for Dependent variable)
#
# 2.Ordinal encoding (Works like label encoding design for independent variables)
#
# 3.One hot encoding (for independent Variable)
#
# 4.Dummie Encoding(same as one hot encoding, delete one of the columns)
#
# 5.Target encoding ( )
#
# 6.Hash Encoding

# %% [markdown]
# Label Encoding  usually used for target variable
#
# When the columns carries weights like (Husband education) column prefer label Encoding
#
#
# **Categorial data :**
#
# *  For the nominal column - One hot encoding
# *   For ordinal column - Ordinal encoding
#
#
#
# **Numerical data :**
# Encoding for handing missing value with mean or maximum
# * Age , continuous - Simple encoding
#
#
#
# **Label encoding vs One hot encoding :**
#
# * Example : Car brand,  color name,  Location name
# For label encoding order works on the encoding value but  the problem solved using One hot encoding

# %% [markdown]
# # Ordinal Encoding

# %%
#only use for independent Variable , Lebel encoding only for target variable .
#Divide the dataset (X=which columns need ordinal encoding, y= Target column)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop('Class label'), axis=1),
                                                    df['Class label'],
                                                    test_size=0.3,
                                                    random_state=0)

X_train.shape, X_test.shape

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder(categories=[['Poor','Average','Good'],['School','UG','PG']])
oe.fit(X_train)

#Accending Order (Poor-0 , Average-1 , )
OrdinalEncoder(categories=[['Poor', 'Average', 'Good'], ['School', 'UG', 'PG']])

# %%
OrdinalEncoder(categories=[['Poor', 'Average', 'Good'], ['School', 'UG', 'PG']])
X_train = oe.transform(X_train)
X_train
oe.categories_
X_train

# %% [markdown]
# # Label Encoding (Target Variable)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(y_train)
le.classes_

# %%
y_train = le.transform(y_train)
y_test = le.transform(y_test)

# %%
# Which back a array so have to transform it DataFrame
y_train

# %%
# Extra thing ML prefer One hot encoding than  Label Encoding

     Codes For one hot Encoding in Pandas:  But don't use in Machine Learning
     pd.get_dummies(df,columns=['fuel','owner'],drop_first=True)
# Out:
#   File "<ipython-input-1-80c072bfc3bf>", line 3
#     Codes For one hot Encoding in Pandas:  But don't use in Machine Learning
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# # One Hot Encoding
# When the categorical data has nominal columns like : Green,blue,black. If we assign green to 0, blue to 1 and black to 2 . That means assign weight to the colors to avoid this use One hot encoding. Used for dependent variables.
#
# one hot encoding converted the value(green) to a vector like
# *   Green [0,1,0]
# *   Red [1,0,0]
# *   Black [0,0,1]
#
#
# If there is 50 values/categories we make 50 different columns. Then apply PCA for dimensinality reducement.

# %% [markdown]
# # Code lecture 27(Campus x)
# So when in 1 dataset have to use multiple encoding have to suggested to use Column Transformer
#
# suppose there are 3 nominal columns with multiple values/categories
#
# 1.   Car brands-40
# 2.   fuel -4
# 3.   Owner-4
#
# As Car brands has a huge amount of values we apply a trick, we consider the most frequent or important categories as unique and other less important categories combine making a category name others.
#
# SO first take 2 columns [fuel,owner] Apply one hot encoding and then take Carbrands apply one hot encoding then combine the array.

# %%
#Divide the Dataset
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.iloc[:,0:4],df.iloc[:,-1],test_size=0.2,random_state=2) # take all the columns
X_train

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(drop='first',sparse=False,dtype=np.int32) # When use decision Tree algoithm not need to drop first because there is no multicolinearit issue

# %%
X_train_new = ohe.fit_transform(X_train[['fuel','owner']]) #take that columns on which we want to apply encoding
X_test_new = ohe.transform(X_test[['fuel','owner']]) # Encode the Train and Test Both

# %%
np.hstack((X_train[['brand','km_driven']].values,X_train_new)) # combine the encoded column with rest of the columns

# %% [markdown]
# **OneHot encoding for top categories (carBrands-40)**

# %%
counts = df['brand'].value_counts()
df['brand'].nunique()
threshold = 100
repl = counts[counts <= threshold].index # Make variable with those cars which has less than 100 options and make a variable for them Unique

pd.get_dummies(df['brand'].replace(repl, 'uncommon')).sample(5)

# %% [markdown]
# # Column Transformer

# %% [markdown]
# **Am Zingegi** (Doing diffenet kind of transformation)

# %%
# adding simple imputer to fever col (Missing Value Replacement)
si = SimpleImputer()
X_train_fever = si.fit_transform(X_train[['fever']])

# also the test data
X_test_fever = si.fit_transform(X_test[['fever']])

X_train_fever.shape

# %%
# Ordinalencoding -> cough
oe = OrdinalEncoder(categories=[['Mild','Strong']])
X_train_cough = oe.fit_transform(X_train[['cough']])

# also the test data
X_test_cough = oe.fit_transform(X_test[['cough']])

X_train_cough.shape

# %%
# OneHotEncoding -> gender,city
ohe = OneHotEncoder(drop='first',sparse=False)
X_train_gender_city = ohe.fit_transform(X_train[['gender','city']])

# also the test data
X_test_gender_city = ohe.fit_transform(X_test[['gender','city']])

X_train_gender_city.shape

# %%
# Extracting Age
X_train_age = X_train.drop(columns=['gender','fever','cough','city']).values

# also the test data
X_test_age = X_test.drop(columns=['gender','fever','cough','city']).values

X_train_age.shape

# %%
X_train_transformed = np.concatenate((X_train_age,X_train_fever,X_train_gender_city,X_train_cough),axis=1)
# also the test data
X_test_transformed = np.concatenate((X_test_age,X_test_fever,X_test_gender_city,X_test_cough),axis=1)

X_train_transformed.shape

# %% [markdown]
# # Mentos Zindagi (Doing different kind of encoding in one place)

# %%
from sklearn.compose import ColumnTransformer

transformer = ColumnTransformer(transformers=[
    ('tnf1',SimpleImputer(),['fever']),
    ('tnf2',OrdinalEncoder(categories=[['Mild','Strong']]),['cough']),
    ('tnf3',OneHotEncoder(sparse=False,drop='first'),['gender','city'])
],remainder='passthrough')

# %%
#Transform the columns

transformer.fit_transform(X_train).shape
transformer.transform(X_test).shape

# %% [markdown]
# # Principal component Analysis (PCA)

# %% [markdown]
# After encoding when coklumn Size is so vast use PCA. Also for reshaping have to use PCA.
#
# PCA doesn't remember existing features , make new type of features and select a new subset from them.
#
# Number of Principal Columns <= Orginal columns of data

# %% [markdown]
# Here in the image the axis rotate and chance the sprade and variance in columns.
#
#
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Why Variance is important**
#
# Spread is not variance ,variance =~ (proportional) spread.
#
# why not use MAD rather than Variance
# Ans: MAD use Mod which is not differenciable at 0, Variance use square which is differenciable.

# %% [markdown]
# KNN type algorithms search for the distance between datapoints so it will confused on Y axis . so Have to maximize the variance.
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Handaling the Imbalanced Dataset
# # After getting classification Report if the Recall of minority class less that means unbalanced dataset impact and caused of bias

# %% [markdown]
# Undesampling Means :
#
# Suppose
#
# 0 - 100 & 1- 900 then class 1 convert to 100 and the total data will be 200 . Loose the data . Data is gold so it's not prefarable .
#
# Oversampling  Means :
#
# Suppose
#
# class 0 - 100 data and class - 900 data . Then Class 0 generates more data and will be turn to 900 data , the total data size will be 1800
#
#
# SMOTE (Synthetic Monitory Oversampling Technique) it's Used for Over Sampling

# %% [markdown]
# # Algorithms Behaviours

# %% [markdown]
# **Logistic Regression**
# 1.   Changes after feature Scaling
# 2.   Changes after feature tranformation(convert the dataset to Normal dataset)
#
#
#
# **Decession Tree**
# 1. Doesn't Changes after feature tranformation(convert the dataset to Normal dataset)
# 2.Doesn't impact after Feature scaling
